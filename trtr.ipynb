# %%
import openai

# %%
# !git clone https://github.com/giriraj191/genaigooglecolab.git
# Out:
# Cloning into 'genaigooglecolab'...
# ...

# %%
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
